# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjidarema/CSC477-HW1/blob/main/Practical_on_Python_Sanjida_Rema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Basic arithmetic operations

a =10
b =5
sum = a+b
difference = a-b
product = a*b
divison = a/b

print("Sum:", sum)
print("differnce:",difference)
print("Product:", product)
print("Divison:", divison)
# Out:
# Sum: 15
# differnce: 5
# Product: 50
# Divison: 2.0

# %%
print(f"The sum of the two numbers {a},{b} is {sum}")
# Out:
# The sum of the two numbers 10,5 is 15

# %%
x = 13//2
print(x)
y = 13 % 2
print(y)
# Out:
# 6
# 1

# %%
x = 10
y = 5

is_greater = x>y
is_equal = x==y
is_not_equal = x !=y
print("Is x greater than y?",is_greater)
print("Is x equal y? ",is_equal )
print("Is x not equal to y?",is_not_equal)
# Out:
# Is x greater than y? True
# Is x equal y?  False
# Is x not equal to y? True

# %%
name = "Sanjida"
age = 26
is_student = True
print(f"{name}'s age is {age}. She is a Student {is_student}")
# Out:
# Sanjida's age is 26. She is a Student True

# %%
def greet(name):
  return "Hello,"+name+ "!"

  greet ("Sanjida")

# %%
def add_numbers(a,b):
  return a+b
a = int(input("Enter first number:"))
b = int(input("Enter Second number"))

addition_value = add_numbers(a,b)
print(f"The result of addition for {a},{b}is {addition_value}")
# Out:
# Enter first number:2
# Enter Second number3
# The result of addition for 2,3is 5

# %%
def add_numbers(a,b):
  return a+b
a =eval(input("Enter first number:"))
b = eval(input("Enter Second number"))

addition_value = add_numbers(a,b)
print(f"The result of addition for {a},{b}is {addition_value}")
# Out:
# Enter first number:-4.5
# Enter Second number10
# The result of addition for -4.5,10is 5.5

# %%
message ="Hello, World"
length = len(message)
uppercase = message.upper()
lowercase = message.lower()
substring = message[7:12]
print("original message", message)
print("The length is", length)
print("Upper case:",uppercase)
print("Lower case:", lowercase)
print("Part of the messageis:", substring)
# Out:
# original message Hello, World
# The length is 12
# Upper case: HELLO, WORLD
# Lower case: hello, world
# Part of the messageis: World

# %%
Last = input("Enter the last name, last name:")
First = input("Enter the last name, first name:")
print(f"{Last},{First}")
# Out:
# Enter the last name, last name:Rema
# Enter the last name, first name:Sanjida
# Rema,Sanjida

# %%
age = int(input("Enter your age:"))
print("You will be", age+1,"years old next year.")
# Out:
# Enter your age:26
# You will be 27 years old next year.

# %%
num1=float(input("Enter a number:"))
num2=float(input("Enter another number"))
sum_result = num1+num2
print("Sum:", sum_result)
# Out:
# Enter a number:12
# Enter another number14
# Sum: 26.0

# %%
city=input("Enter your city")
Country = input("Enter your country")
location = city +","+ Country
print("You are in:",location)
# Out:
# Enter your cityNew York
# Enter your countryUnited States
# You are in: New York,United States

# %%
name, age = input("Enter your name and age sperated by space: ").split()
print(f"my name is {name} and my age is {age}")
# Out:
# Enter your name and age sperated by space: Sanjida 26
# my name is Sanjida and my age is 26
